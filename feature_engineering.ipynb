# %%
import warnings
warnings.filterwarnings('ignore')

import seaborn as sb

# %%
# %store -r new_df

# %%
new_df.corr().style.background_gradient(cmap ='RdYlBu')
# Out:
# <style  type="text/css" >
# ...

# %%
new_df = new_df.drop(['FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE'], axis = 1).fillna(0)

# %%
# %store new_df
# Out:
# Stored 'new_df' (DataFrame)
